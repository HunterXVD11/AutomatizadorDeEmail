# %% [markdown]
# Primeira vez usando Jupiter

# %%
import pyautogui
import time
import pyperclip
import pandas as pd

pyautogui.PAUSE = 2

#abrir o navegador
pyautogui.press("win")
pyautogui.write("opera")
pyautogui.press("enter")

#entrar no link
pyautogui.write("https://pages.hashtagtreinamentos.com/aula1-intensivao-sistema")
pyautogui.press("enter")
time.sleep(5)

#preencher o login
pyautogui.click(x = 648,y = 343)
pyautogui.write("meu_login")

#preencher a senha
pyautogui.click(x = 624,y = 421)
pyautogui.write("minha_senha")

#apertar em acessar
pyautogui.click(x = 681,y = 489)
time.sleep(3)

#baixar tabela
pyautogui.click(x = 522,y = 355)
pyautogui.click(x = 642,y = 641)

#encontrar e ler a tabela
tabela = pd.read_csv(r"C:/Users/isral/Downloads/Compras.csv", sep= ";")
display(tabela)

total_gasto = tabela["ValorFinal"].sum()
quantidade = tabela["Quantidade"].sum()
preco_medio = total_gasto/quantidade

#enviar email com dados
pyautogui.hotkey("ctrl","t")
pyautogui.click(x = 465,y = 46)
pyautogui.write("https://mail.google.com/mail/u/0/")
pyautogui.press("enter")
time.sleep(5)

pyautogui.click(x = 121,y = 166)
#pyautogui.write("carolina.navarrofs@gmail.com")
pyautogui.write("isra.lemes@gmail.com")
pyautogui.press("tab") #Primeiro tab para concluir o texto do email desejado
pyautogui.press("tab") #Segundo tab para mudar para a sessão assunto

pyperclip.copy("Relatório de Compras")
pyautogui.hotkey("ctrl","v")
pyautogui.press("tab")

texto = f"""
Prezados,
Segue resumo de compras:

Gasto Total: R${total_gasto:,.2f}
Quantidade: {quantidade:,}
Preço Médio: {preco_medio:,.2f}

Qualquer dúvida, é só falar
Att. Israel
"""

pyperclip.copy(texto)
pyautogui.hotkey("ctrl","v")

pyautogui.hotkey("ctrl","enter")
# Out:
#       CódigoCompra        Data               Fornecedor  \
# 0            65014  01/12/2023   Fabrica Hashtag Brasil
# 1            65014  01/12/2023   Fabrica Hashtag Brasil
# 2            65016  01/12/2023   Fabrica Doidona Brasil
# 3            65016  01/12/2023   Fabrica Doidona Brasil
# 4            65017  01/12/2023  Original Fábrica Brasil
# ...            ...         ...                      ...
# 4538         69996  26/12/2023        Revenda Argentina
# 4539         69996  26/12/2023        Revenda Argentina
# 4540         69996  26/12/2023        Revenda Argentina
# 4541         69997  26/12/2023   Fabrica Doidona Mexico
# 4542         69997  26/12/2023   Fabrica Doidona Mexico
#
#                             Produto  Quantidade  ValorUnitário  ValorFinal
# 0              Óleo Motor - Linha A           5         259.00     1295.00
# 1           Kit Embreagem - Linha A           1         380.00      380.00
# ...

# %%
time.sleep(5)
print(pyautogui.position())
# Out:
# Point(x=121, y=166)
